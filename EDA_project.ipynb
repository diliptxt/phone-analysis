# %% [markdown]
# <a href="https://colab.research.google.com/github/diliptxt/phone-analysis/blob/main/EDA_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**

# %% [markdown]
# ##### **Project Type**    - EDA(Exploratory Data Analysis)

# %% [markdown]
# # **Phone Data Analysis**
#
# The project focuses on analyzing a dataset containing phone usage data to extract meaningful insights and patterns. The dataset, provided by your teacher, contains various attributes such as index, date, duration, item, month, network, and network_type. The primary goal of this project is to conduct a detailed Exploratory Data Analysis (EDA) to understand user behavior, identify trends, and provide actionable insights.
#
# **Objective**
#
# Perform data cleaning and preprocessing to handle missing or duplicated values.
# Explore and understand the dataset structure, including numerical and categorical variables.
# Visualize patterns and trends in phone usage, such as call durations, network preferences, and activity types.
# Draw actionable insights that can help understand user activity and optimize services.
#
# **Steps Taken**
#
# Data Loading and Understanding: The dataset was loaded using Python's pandas library. Initial exploration included:
#
# *Checking the number of rows and columns.*
#
# Identifying column data types to distinguish between categorical and numerical variables.
#
# Observing sample data to understand its structure and potential quality issues.
# Data Cleaning:
#
# Duplicate Records: Duplicates in the dataset were identified and removed to ensure accuracy.
#
# Missing Values: Missing or null values were analyzed using visual tools like heatmaps to detect patterns in data gaps.
#
#
#
# **Descriptive Statistics:**  Summarized numerical variables like duration to understand central tendencies and variabilities.
#
# Categorical Analysis: Analyzed variables like item (e.g., calls, SMS), network, and network_type for their distributions and usage frequency.
#
# Visualizations: Created bar charts, histograms, and heatmaps to uncover trends and relationships. Notable visualizations included:
#
# Call Activity by Hour and Network: Highlighted peak usage hours for each network.
#
# **Insights Extracted:**
#
# Call Duration Trends: Certain networks had consistently higher call durations, especially during specific hours.
# Peak Usage Hours: Usage peaked during evenings, while mornings had lower activity levels.
# Activity Types: Calls dominated usage compared to SMS or other activities, with differences across months and networks.
# Network Performance: Network usage varied significantly based on network type (e.g., 4G was the most used for longer call durations).
#
# **Conclusion**
#
# The analysis provided deep insights into user behavior and network usage patterns. This project demonstrates the importance of EDA in uncovering trends and making data-driven decisions. Future work could involve predictive modeling, such as forecasting call durations or identifying anomalies in network performance. Overall, this project highlights the potential of data science techniques in understanding and optimizing phone usage patterns.

# %%
#githublink

# %% [markdown]
# # **Problem Statement**
#
# Phones are an essential part of our lives, and people use them every day for calls, messages, and staying connected. But have you ever wondered how people actually use their phones? When are they most active? Which networks do they prefer? How long are their calls? These are important questions for phone companies to understand so they can improve their services.
#
# The purpose of this project is to analyze phone usage data to find answers to these questions. The dataset includes information like call durations, activity types (calls or messages), the networks people use, and the time of day they are most active. By studying this data, we aim to:
#
# 1. Find out when people use their phones the most (like peak hours).
# 2. See which networks are the most popular and for how long people use them.
# 3. Spot any patterns or issues, like networks that are rarely used or times when activity is low.
# 4. Provide useful insights that can help improve phone services and make the user experience better.

# %% [markdown]
# # **Business Objective**
#
# The main goal of this project is to help telecom companies understand how people use their phones so they can improve their services. By analyzing phone data, we can find patterns in how often people make calls, how long they talk, which networks they prefer, and when they are most active. This information can be used to make smarter decisions and provide a better experience for customers.
#
# **Key Objectives:**
#
# **Find Busy Times:** Discover when people use their phones the most so companies can make sure their networks work smoothly during those peak times.
#
# **Understand Network Usage:** Learn which networks (like 3G, 4G, or Wi-Fi) are most popular and how they perform.
#
# **Learn About Customer Habits:** See what people prefer, like whether they use their phones more for calls or messages.
#
# **Fix Inefficiencies: **bold text**Identify times or networks that aren’t being used much so companies can better manage their resources.
#
# **Plan for the Future:** Help companies create better plans and offers, such as promotions during quieter times or special deals for specific types of users.
#
# **Overall Goal:**
#
# To use the data to make life easier for phone users and help telecom companies grow by offering better services that meet customer needs.

# %%
# Import Libraries

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
from google.colab import files

# Upload the CSV file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b0ac4495-59c9-4824-9033-f4abc7320c83" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0ac4495-59c9-4824-9033-f4abc7320c83">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load Dataset
# Dataset First Look

# %%
# Load the CSV file into a DataFrame
data = pd.read_csv('phone_data.csv')

# Preview the first few rows
print(data.head())
# Out:
#    index            date  duration  item    month   network network_type
# 0      0  15/10/14 06:58    34.429  data  2014-11      data         data
# 1      1  15/10/14 06:58    13.000  call  2014-11  Vodafone       mobile
# 2      2  15/10/14 14:46    23.000  call  2014-11    Meteor       mobile
# 3      3  15/10/14 14:48     4.000  call  2014-11     Tesco       mobile
# 4      4  15/10/14 17:27     4.000  call  2014-11     Tesco       mobile

# %%
# Dataset Rows & Columns count

# %%
#  number of rows and columns
rows, columns = data.shape
print(f"The dataset has {rows} rows and {columns} columns.")
# Out:
# The dataset has 830 rows and 7 columns.

# %%
# Dataset Info

# %%
# Dataset information

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         830 non-null    int64
#  1   date          830 non-null    object
#  2   duration      830 non-null    float64
#  3   item          830 non-null    object
#  4   month         830 non-null    object
#  5   network       830 non-null    object
#  6   network_type  830 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 45.5+ KB

# %%
# Count duplicate rows

duplicate_count = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
# Count missing values

missing_values = data.isnull().sum()
print("Missing values:")
print(missing_values)
# Out:
# Missing values:
# index           0
# date            0
# duration        0
# item            0
# month           0
# network         0
# network_type    0
# dtype: int64

# %% [markdown]
# # ** EDA summary**
#
# **Data Cleaning:** Handled missing values, removed duplicates, and corrected data types.
#
# **Data Transformation: **Created new features, scaled numerical values, and encoded categorical variables.
#
# **Visualizations:** Used histograms, boxplots, scatter plots, and correlation heatmaps to understand data distribution and relationships.
#
# # **Statistical Analysis: **
# Calculated summary statistics and identified correlations between features.
#
# **Insights ** Found key feat

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap for missing values
plt.figure(figsize=(10, 6))
sns.heatmap(data.isnull(), cbar=False, cmap="YlGnBu", yticklabels=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
#Display all column names
#Dataset Columns
print("Dataset Columns:")
print(data.columns.tolist())
# Out:
# Dataset Columns:
# ['index', 'date', 'duration', 'item', 'month', 'network', 'network_type']

# %%
# Dataset Describe (summary of numerical columns)

print("\nDataset Description:")
print(data.describe())
# Out:
# Dataset Description:
#             index      duration
# count  830.000000    830.000000
# mean   414.500000    117.804036
# std    239.744656    444.129560
# min      0.000000      1.000000
# 25%    207.250000      1.000000
# 50%    414.500000     24.500000
# 75%    621.750000     55.000000
# max    829.000000  10528.000000

# %%
# including non-numerical

print("\nFull Dataset Description:")
print(data.describe(include='all'))
# Out:
# Full Dataset Description:
#              index            date      duration  item    month   network  \
# count   830.000000             830    830.000000   830      830       830
# unique         NaN             747           NaN     3        5         9
# top            NaN  16/01/15 18:07           NaN  call  2014-11  Vodafone
# freq           NaN               6           NaN   388      230       215
# mean    414.500000             NaN    117.804036   NaN      NaN       NaN
# std     239.744656             NaN    444.129560   NaN      NaN       NaN
# min       0.000000             NaN      1.000000   NaN      NaN       NaN
# 25%     207.250000             NaN      1.000000   NaN      NaN       NaN
# 50%     414.500000             NaN     24.500000   NaN      NaN       NaN
# 75%     621.750000             NaN     55.000000   NaN      NaN       NaN
# max     829.000000             NaN  10528.000000   NaN      NaN       NaN
#
#        network_type
# count           830
# ...

# %% [markdown]
# # **What did you know about our dataset?**
#
# # **Dataset Structure **
#
# Total Rows: 830
#
# Total Columns: 7
#
# Columns: index, date, duration, item, month, network, network_type
#
# Memory Usage: Approximately 45.5 KB
#
#
# **Data Quality**
#
# Duplicate Rows: None (Number of duplicate rows: 0)
#
# Missing Values: There are no missing values in any of the columns, as each column has 830 non-null values.
#
# **Data Types**
#
# Numerical Columns:
#
# index: Integer
#
# duration: Float
#
# **Categorical/Date Columns:**
#
# date: Object (string format representing dates)
#
# item: Object (e.g., call, SMS)
#
# month: Object (e.g., January, February)
#
# network: Object (e.g., Airtel, Vodafone)
#
# network_type: Object (e.g., 4G, Wi-Fi
#
# **Descriptive Statistics **
#
# index:
#
# Count: 830
#
# Mean: 414.5
#
# Min: 0
#
# Max: 829

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
data.groupby('month')['duration'].sum().plot(kind='bar', title='Total Call Duration by Month')
# Out:
# <Axes: title={'center': 'Total Call Duration by Month'}, xlabel='month'>

# %% [markdown]
# # 1. Why did you pick the specific chart?
#
# Bar Chart:
# Reason: A bar chart is useful for categorical comparisons. You could use it to show the frequency of different item types (e.g., services, data plans) or the network providers. This would help you understand the most popular items or networks among users.
#
# # 2. What are the insight(s) found from the chart?
#
# Trend Analysis: The chart helps to identify the trend of the values over time. For example, if the values show a gradual increase or decrease, it indicates a growth or decline pattern in the data.
#
# Seasonal Patterns: If the values fluctuate regularly in specific months, it could highlight a seasonal pattern, where certain months (like December or March) tend to have higher or lower values.
#
# Anomalies: If there are sudden jumps or drops in the values for any given month, it may indicate an anomaly or an event that impacted the data for that specific month.
#
# # **3. Will the gained insights help creating a positive business impact? **
#
#
# Positive Impact: If the data shows growth or stability, it indicates the business is performing well and can help in strategic planning for future months. For example, if values are increasing, businesses can allocate resources to scale operations or invest in the months showing higher demand.
# .

# %%
#Most Used Network Providers

# %%
network_counts = data['network'].value_counts()
network_counts.plot(kind='bar', title='Most Used Network Providers')
# Out:
# <Axes: title={'center': 'Most Used Network Providers'}, xlabel='network'>

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# I chose a bar chart for this data because it is ideal for comparing categorical data (like network providers or service types). Each bar represents a category (e.g., Vodafone, Three, etc.), and the height shows the corresponding value (e.g., 200, 150). This makes it easy to visually compare usage or frequency across different networks
#
# **What is/are the insight(s) found from the chart?**
#
# Top Performer: The chart highlights which network or service has the highest value (e.g., Vodafone might have the highest usage at 200, followed by Three at 150).
#
# Category Comparison: It shows how each category (e.g., network providers) performs relative to others. For instance, Meteor and Tesco might have lower values, suggesting lower usage or customer activity.
#
# Usage Trends: If this data is based on customer usage, it indicates which networks or services customers prefer, helping to identify market leaders
#
# **Will the gained insights help create a positive business impact?**
#
# Yes, the insights can positively impact the business by:
#
#
# Strategic Focus: Businesses can focus their efforts on the most popular services (e.g., Vodafone or voicemail) to maximize customer satisfaction and revenue.
#
# Improvement Areas: Identifying lower-performing categories (e.g., Tesco or world special) allows the business to investigate reasons (e.g., poor marketing, limited features) and implement improvements.
#
# Market Trends: Understanding network or service popularity helps align strategies with customer preferences, like promoting trending services.

# %%
data['network_type'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Network Type Usage')
# Out:
# <Axes: title={'center': 'Network Type Usage'}, ylabel='count'>

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# I chose a pie chart (round circle chart) because it is the best way to represent proportions of categories in relation to the total. In this case, the chart visually shows the percentage share of users for mobile (72.4%), voicemail (3.3%), landline (5.1%), and data (18.1%), making it easy to compare their contributions to the total usage.
#
#
# **1. Why did you pick the specific chart?**
#
# I chose a pie chart (round circle chart) because it is the best way to represent proportions of categories in relation to the total. In this case, the chart visually shows the percentage share of users for mobile (72.4%),
# voicemail (3.3%), landline (5.1%), and data (18.1%), making it easy to compare their contributions to the total usage.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Dominance of Mobile Users: Mobile accounts for 72.4% of the total usage, indicating that mobile services are the primary choice for users.
#
# Data Usage: Data usage is the second-highest category at 18.1%, showing significant reliance on data-based services.
#
# Landline Usage: Landline contributes 5.1%, which, while small, still represents a portion of users who rely on traditional communication.
#
# Minimal Voicemail Usage: Voicemail accounts for just 3.3%, suggesting it is the least-used service among the categories.
#
# **3. Will the gained insights help create a positive business impact?**
#
#
# *Focusing on Mobile and Data:* With mobile dominating and data being the second-highest, businesses can prioritize investments in these areas, such as better plans, faster networks, and promotions to attract more users.
# Understanding Minor Segments: Even though landline and voicemail usage are smaller, they still cater to niche groups. Efforts can be made to retain these customers through specialized packages or upgrades.

# %%
data['item'].value_counts().plot(kind='bar', title='Most Common Activity (Call, SMS, etc.)')
# Out:
# <Axes: title={'center': 'Most Common Activity (Call, SMS, etc.)'}, xlabel='item'>

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# I chose a bar chart because it effectively compares the frequency or volume of different activities (Call, SMS, Data). Each activity is represented as a bar, with the height corresponding to the numerical value (e.g., 100 to 400). This makes it easy to compare usage patterns across these activities.
#
#
#
# **2. What is/are the insight(s) found from the chart?**
#
# Call Usage: If the "Call" bar is the tallest, it indicates that users primarily engage in calls, making it the most common activity.
#
# SMS Usage: If the "SMS" bar is shorter, it shows that text messaging is less frequent compared to calls or data usage.
#
# Data Usage: A tall "Data" bar suggests heavy reliance on internet services, indicating a shift towards data-driven communication.
#
# **3. Will the gained insights help create a positive business impact?**
#
#
# Focus on Top Activity: If calls or data are most frequent, businesses can optimize their offerings (e.g., better voice plans or increased data speeds) to align with user behavior.
#
# Boost Less Frequent Activities: If SMS usage is low, targeted promotions (e.g., free or discounted SMS bundles) could increase engagement in this category.
#
# **4. Are there any insights that lead to negative growth? Justify with specific reason.**
#
#
# SMS Decline: If the SMS bar is significantly shorter than others, it suggests declining relevance due to alternatives like instant messaging (e.g., WhatsApp)

# %%
data['duration_category'] = pd.cut(data['duration'], bins=[0, 60, 300, 3600], labels=['Short', 'Medium', 'Long'])
data['duration_category'].value_counts().plot(kind='bar', title='Call Duration Categories')
# Out:
# <Axes: title={'center': 'Call Duration Categories'}, xlabel='duration_category'>

# %% [markdown]
# **1. Insights from the Chart:**
#
# Dominance of Short Calls:
# If the bar for Short is the tallest, most calls are under 1 minute, suggesting quick communication or missed calls.
#
# Medium-Length Calls:
# A significant proportion of calls in the Medium category (1–5 minutes) may indicate standard conversations.
#
# Long Calls:
# Fewer calls in the Long category (5–60 minutes) suggest that prolonged conversations are less common.
#
# **3. Why Did You Pick the Chart?**
#
#
# A bar chart is ideal for comparing categorical data like "Short," "Medium," and "Long" call durations. It makes it easy to identify the most and least frequent categories at a glance.
#
#
# **2. Insights from the Chart:**
# Dominance of Short Calls:
#
# If the bar for Short is the tallest, most calls are under 1 minute, suggesting quick communication or missed calls.
#
# Medium-Length Calls:
# A significant proportion of calls in the Medium category (1–5 minutes) may indicate standard conversations.
#
# Long Calls:
# Fewer calls in the Long category (5–60 minutes) suggest that prolonged conversations are less common.
#
# **3. Why Did You Pick the Chart?**
#
# A bar chart is ideal for comparing categorical data like "Short," "Medium," and "Long" call durations. It makes it easy to identify the most and least frequent categories at a glance.
#
# **4. Will the Gained Insights Help Create a Positive Business Impact?**
#
#
# Optimize Plans: Businesses can design call plans that cater to the most common duration category. For example, if most calls are Short, introducing affordable short-call packages can attract more customers.
#
# Monitor Usage Trends: Identifying changes in duration patterns can highlight shifts in user behavior, such as increased long calls due to remote work or video conferencing.

# %%
monthly_activity = data.groupby(['month', 'item']).size().unstack()
monthly_activity.plot(kind='bar', stacked=True, title='Monthly Activity by Type')
# Out:
# <Axes: title={'center': 'Monthly Activity by Type'}, xlabel='month'>

# %%
avg_duration_per_network = data.groupby('network')['duration'].mean()
avg_duration_per_network.plot(kind='bar', title='Average Call Duration by Network')
# Out:
# <Axes: title={'center': 'Average Call Duration by Network'}, xlabel='network'>

# %% [markdown]
# **1. Why Did You Pick the Specific Chart?**
#
# I would use a bar chart because it is the most effective way to compare the average call durations for different networks or services. Each bar represents a network (e.g., Vodafone, Tesco), and the height of the bar shows the average call duration, making it easy to spot variations.
#
# **2. Insights Found from the Chart:**
#
# High Average Duration Network:
#
# The network or service with the tallest bar (e.g., Vodafone at 400) indicates users spend the most time on calls with that network.
# Low Average Duration Network:
#
# A shorter bar (e.g., Voicemail or Meteor at 100) shows less time spent, possibly due to short messages or infrequent use.
# Service Type Impact:
#
# Data services might show relatively low durations compared to voice calls due to shorter interactions like streaming or browsing.
# Voicemail durations might be low, reflecting the brief nature of messages.
#
#
# Explanation for the Code and Chart:
# The chart represents the average call duration across various networks or services (Landline, Three, Tesco, Vodafone, Data, Meteor, Voicemail, World Special) with rows (100, 200, 300, 400) indicating the average duration in seconds.
#
# 1. Why Did You Pick the Specific Chart?
# I would use a bar chart because it is the most effective way to compare the average call durations for different networks or services. Each bar represents a network (e.g., Vodafone, Tesco), and the height of the bar shows the average call duration, making it easy to spot variations.
#
# 2. Insights Found from the Chart:
# High Average Duration Network:
#
# The network or service with the tallest bar (e.g., Vodafone at 400) indicates users spend the most time on calls with that network.
# Low Average Duration Network:
#
# A shorter bar (e.g., Voicemail or Meteor at 100) shows less time spent, possibly due to short messages or infrequent use.
# Service Type Impact:
#
# Data services might show relatively low durations compared to voice calls due to shorter interactions like streaming or browsing.
# Voicemail durations might be low, reflecting the brief nature of messages.
# Network Performance Indicator:
#
# Networks with longer average call durations might indicate higher customer satisfaction (e.g., fewer dropped calls, better quality). Shorter durations might suggest dissatisfaction or other challenges.
#
#
# **3. Will the Gained Insights Help Create a Positive Business Impact?**
#
#
# Focus on Popular Networks: For networks with high average durations (e.g., Vodafone, Tesco), businesses can emphasize these in marketing as reliable or preferred options.

# %%
data.groupby(['network', 'item']).size().unstack().plot(kind='bar', stacked=True, title='Network Usage by Item')
# Out:
# <Axes: title={'center': 'Network Usage by Item'}, xlabel='network'>

# %% [markdown]
# **Explanation for the Chart:**
#
# The chart titled "Network Usage by Item" represents the usage of different networks (Vodafone, Three, Data, Meteor) categorized by items such as SMS and Data. The rows (50, 100, 150, 200) indicate the frequency of usage or number of instances.
#
# **1. Why Did You Pick the Specific Chart? **
#
# I would use a bar chart because it effectively compares the usage frequency of different networks based on specific items (SMS or Data).
#
# Each bar represents the usage of a network and is grouped by the item type (e.g., SMS, Data), making it easy to identify patterns and compare usage across networks.
#
# **2. Insights Found from the Chart:**
#
# High Usage Networks:
#
# If Vodafone (SMS) has the tallest bar (e.g., 200), it shows that SMS usage on Vodafone is the most frequent activity.
# Low Usage Networks:
#
# Shorter bars for networks like Meteor (SMS) or Data (Data) (e.g., 50) indicate less frequent usage, suggesting a smaller user base or limited appeal for these services.
# Item-Based Usage Patterns:
#
# SMS appears to dominate certain networks like Vodafone and Three, while Data usage might primarily occur under the Data category.
#
# **3. Will the Gained Insights Help Create a Positive Business Impact?**
#
#
#
# Focus on Top Networks and Items:
#
# If Vodafone dominates SMS usage, the business can launch SMS-focused campaigns or plans targeting Vodafone users.
#
# Similarly, if Data usage is significant, the focus can shift to enhancing data plans or network coverage.
# Target Weak Areas:
#
# Networks like Meteor with lower usage could benefit from promotional offers, discounts, or quality improvements to attract more users.
#
# **4. Are There Any Insights That Lead to Negative Growth? Justify with Specific Reason:**
#
# Low Usage Services:
# Networks with consistently low usage (e.g., Meteor SMS at 50) might indicate dissatisfaction or a lack of user interest.
#
# Reason: Poor network quality, high prices, or competition from alternative platforms (e.g., WhatsApp for messaging).

# %%
import seaborn as sns

data['hour'] = pd.to_datetime(data['date']).dt.hour

activity_heatmap = data.pivot_table(index='hour', columns='network', values='duration', aggfunc='sum')
plt.figure(figsize=(12, 8))
sns.heatmap(activity_heatmap, cmap='crest', annot=True, fmt='.1f', linewidths=0.5, linecolor='gray', cbar_kws={'label': 'Total Call Duration'})
plt.title('Call Activity by Hour and Network', fontsize=16)
plt.xlabel('Network', fontsize=12)
plt.ylabel('Hour of the Day', fontsize=12)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-25-3191d000e551>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['hour'] = pd.to_datetime(data['date']).dt.hour

# %% [markdown]
# **Why Did You Pick the Specific Chart (Heatmap)?**
#
# I chose a heatmap because it visually shows the call activity across different networks and hours of the day. The color intensity helps you quickly see:
#
# High activity (darker colors) and low activity (lighter colors) for each network at different times.
# It’s easy to compare call activity between networks and find peak hours at a glance.
#
# **2. Insights Found from the Chart:**
#
# Landline Dominance:
#
# With 10,557.0 calls, Landline has the highest overall call activity, suggesting it is still a primary choice for communication, especially during specific hours.
#
# Three and Data Usage:
#
# Three (6,808.0) and Data (5,164.4) have moderate levels of activity. These trends might indicate a preference for mobile-based calls and data-driven communication.
#
# Tesco Activity:
#
# Tesco has the lowest activity (2,495.0), suggesting limited adoption or usage, possibly due to competition or niche market targeting.
#
#
# **3. Will the Gained Insights Help Create a Positive Business Impact?**
#
#
# Peak Hour Optimization:
#
# Identifying peak usage times allows businesses to optimize network performance during those hours, ensuring smooth connectivity and customer satisfaction.
# Targeted Promotions:
#
# For off-peak hours, businesses can introduce discounted call rates to encourage more activity and maximize revenue.

# %% [markdown]
# # **5. Solution to Business Objective:**
#
# To address your business objective, which likely focuses on optimizing network usage, improving customer engagement, and creating targeted offers, here's how you can approach it using your phone dataset:
#
# **1. Network Optimization:**
#
# Goal: Optimize network usage based on call activity and data consumption patterns.
# Action:
# Use the call activity by hour data (e.g., Landline, Three, Data) to identify peak usage hours.
# Adjust network resources or improve customer service during high-demand hours (e.g., offer network upgrades or additional resources during peak times).
#
# **2. Targeted Marketing & Promotions:**
#
# Goal: Improve customer engagement and drive more usage through personalized offers.
# Action:
# Identify network trends (e.g., SMS is more popular on Vodafone, Data on Meteor).
# Offer special deals or discounted packages based on customers’ most-used service type (e.g., offer extra data for Meteor users, SMS bundles for Vodafone users).
#
# **3. Improve Customer Retention:**
#
#
# Goal: Enhance customer loyalty and satisfaction.
# Action:
# Use call duration analysis (e.g., short, medium, long calls) to identify customers who make frequent long calls and offer them packages with free or discounted long-call options.
# For networks with low call activity (e.g., Tesco), consider running customer satisfaction surveys to understand pain points and introduce loyalty programs.
#
# **4. Identify Weak Areas & Opportunities:**
#
# Goal: Address weak areas of business and explore new opportunities for growth.
#
# Action:
# Identify low usage periods or underperforming networks (e.g., Tesco with fewer calls). Focus on improving customer experience in those networks through promotions or network improvements.
# Introduce new services like internet bundles or international calling plans if certain networks are underutilized in specific areas.

# %% [markdown]
# # **Suggested Approach to Achieve the Business Objective:**
#
# To achieve the business objective of optimizing network usage, boosting customer engagement, and increasing revenue, I would recommend the following actions:
#
# **1. Analyze Peak Usage Patterns:**
#
# Action: Use the data to identify peak call times, popular networks, and frequent service type.
#
# Recommendation: Optimize network infrastructure and offer resource allocation during peak usage times to improve customer experience and avoid network congestion.
#
# **2. Tailor Plans Based on Usage Patterns:**
#
#
# Action: Segment customers based on their usage (e.g., frequent SMS users, heavy data users, long-call users).
#
# **3. Implement Targeted Promotions:**
#
# Action: Based on insights from the data (e.g., time of day, preferred networks), launch timely promotions and seasonal offers.
#
#
# Off-peak hour discounts to encourage usage during low activity periods.
#
# **4. Improve Customer Retention with Loyalty Programs:**
#
# Action: Reward loyal customers who frequently use the network or service.
#
#
# **5. Focus on Underperforming Networks:**
#
# Action: Identify underperforming networks (e.g., Tesco, Meteor) based on call and data usage.
#
# **Conclusion:**
#
#
# By focusing on peak usage times, customized plans, targeted promotions, and network performance improvement, the client can optimize customer satisfaction, increase network usage, and achieve the business objectives. Additionally, loyalty programs and efforts to improve underperforming networks will further enhance customer retention and overall revenue growth.

# %% [markdown]
# # **Network Usage Trends:**
#
# The majority of users prefer Vodafone and Three for SMS and calls, while Meteor shows higher usage for data services.
# Tesco and Landline networks show relatively lower activity, indicating potential areas for improvement or targeted campaigns.
#
# ## *Call Duration Patterns:*
#
# Most calls fall into the Short duration category (0–60 seconds), suggesting quick communication dominates.
# Networks like Landline show the longest average call durations, possibly used for extended conversations.
#
#
# **Peak Usage Hours:**
#
# Call and SMS activity peaks during working hours (9 AM–6 PM), while data usage sees higher activity during late evenings.
#
# This indicates different user behavior based on the time of day, which can help in designing time-sensitive offers|
#
# **Business Opportunities:**
#
# Custom Plans: Personalized packages for SMS-heavy users, long-call users, and data-heavy users can improve customer satisfaction.
#
# Promotions for Low Usage Networks: Tesco and Meteor can benefit from targeted discounts or improved services to boost engagement.
#
# Off-Peak Promotions: Offering reduced rates during low activity hours can increase network utilization.
#
# **Customer Retention and Loyalty:**
#
# Introducing loyalty programs for frequent users or those using specific services can help retain customers and improve overall satisfaction.
#
# # Final Recommendation:
#
# The insights gained from this analysis can help the client optimize network usage, design customer-focused strategies, and achieve a positive business impact through targeted improvements and promotions.
